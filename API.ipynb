# %%
import requests
import json
import pprint


website_url = "https://www.metaweather.com"
search_api = "/api/location/search/?query={}"

city = input("Enter your city: ")

search_api_city = search_api.format(city)
search_api_final_link = website_url + search_api_city

website_data = requests.get(search_api_final_link).content

parsed_data = json.loads(website_data)

weather_url = "https://www.metaweather.com/api/location/" + str(parsed_data[0]["woeid"])

website_data = requests.get(weather_url).content

parsed_weather = json.loads(website_data)

for i in range(6):
    print(f"Day{i} weather: ")
    weather_data = parsed_weather["consolidated_weather"][i]
    pprint.pprint(weather_data)

# if parsed_weather["consolidated_weather"][0]["humidity"] > 80:
# #     print("RAIN RAIN GO AWAY, COME AGAIN ANOTHER CENTURY")
#     rain = True
# else:
# #     print("G'DAY MATE!")
#     rain = False

# if parsed_weather["consolidated_weather"][0]["max_temp"] > 35:
#     hot = True
# else:
#     hot = False
    
# if rain == True and hot == True:
#     print("HOW DOES IT RAIN WHEN IT'S SO HOT?")
# elif rain == True and hot == False:
#     print("CAN I BORROW A BED FOR A DAY?")
# elif rain == False and hot == True:
#     print("KOI DERMI COOL DO YAAR")
# else:
#     print("DERMI COOL KISNE LAGAYA?")
# Out:
# Enter your city: delhi
# Day0 weather:
# {'air_pressure': 1003.005,
#  'applicable_date': '2019-05-10',
#  'created': '2019-05-10T04:04:43.378576Z',
#  'humidity': 19,
#  'id': 6331265038942208,
#  'max_temp': 39.18,
#  'min_temp': 29.994999999999997,
#  'predictability': 70,
#  'the_temp': 40.1,
#  'visibility': 10.263809353376281,
#  'weather_state_abbr': 'lc',
#  'weather_state_name': 'Light Cloud',
#  'wind_direction': 281.1493550255011,
#  'wind_direction_compass': 'W',
#  'wind_speed': 7.674853514234205}
# Day1 weather:
# {'air_pressure': 1006.075,
#  'applicable_date': '2019-05-11',
#  'created': '2019-05-10T04:04:46.494714Z',
#  'humidity': 22,
#  'id': 6183262848286720,
#  'max_temp': 39.260000000000005,
#  'min_temp': 29.12,
#  'predictability': 70,
#  'the_temp': 39.265,
#  'visibility': 10.855976099578463,
#  'weather_state_abbr': 'lc',
#  'weather_state_name': 'Light Cloud',
#  'wind_direction': 305.08864277474134,
#  'wind_direction_compass': 'NW',
#  'wind_speed': 5.210348188910098}
# Day2 weather:
# {'air_pressure': 1004.5,
#  'applicable_date': '2019-05-12',
#  'created': '2019-05-10T04:04:49.445655Z',
#  'humidity': 21,
#  'id': 5348873042132992,
#  'max_temp': 39.75,
#  'min_temp': 29.055,
#  'predictability': 70,
#  'the_temp': 40.03,
#  'visibility': 10.873995864153343,
#  'weather_state_abbr': 'lc',
#  'weather_state_name': 'Light Cloud',
#  'wind_direction': 307.7118479188967,
#  'wind_direction_compass': 'NW',
#  'wind_speed': 5.205504538293698}
# Day3 weather:
# {'air_pressure': 1003.4449999999999,
#  'applicable_date': '2019-05-13',
#  'created': '2019-05-10T04:04:52.457219Z',
#  'humidity': 22,
#  'id': 5560423870889984,
#  'max_temp': 40.285,
#  'min_temp': 31.125,
#  'predictability': 73,
#  'the_temp': 39.515,
#  'visibility': 10.862189811500835,
#  'weather_state_abbr': 's',
#  'weather_state_name': 'Showers',
#  'wind_direction': 262.5748062121078,
#  'wind_direction_compass': 'W',
#  'wind_speed': 4.6308564165752015}
# Day4 weather:
# {'air_pressure': 1003.4449999999999,
#  'applicable_date': '2019-05-14',
#  'created': '2019-05-10T04:04:55.449567Z',
#  'humidity': 28,
#  'id': 5174741981724672,
#  'max_temp': 38.254999999999995,
#  'min_temp': 29.605,
#  'predictability': 73,
#  'the_temp': 38.614999999999995,
#  'visibility': 9.663564781675017,
#  'weather_state_abbr': 's',
#  'weather_state_name': 'Showers',
#  'wind_direction': 311.5287381562502,
#  'wind_direction_compass': 'NW',
#  'wind_speed': 3.768808266359129}
# Day5 weather:
# {'air_pressure': 1003.37,
#  'applicable_date': '2019-05-15',
#  'created': '2019-05-10T04:04:58.505773Z',
#  'humidity': 30,
#  'id': 6472466819973120,
#  'max_temp': 36.775000000000006,
#  'min_temp': 28.23,
#  'predictability': 73,
#  'the_temp': 38.01,
#  'visibility': 9.61882605583393,
#  'weather_state_abbr': 's',
#  'weather_state_name': 'Showers',
#  'wind_direction': 63.0,
#  'wind_direction_compass': 'ENE',
#  'wind_speed': 2.8597281873856675}
