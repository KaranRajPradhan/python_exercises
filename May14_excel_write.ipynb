# %%
#### from openpyxl import Workbook

prompt = "->"

wb = Workbook()

#grab the active worksheet
ws = wb.active

#Data can be assigned directly to cells
# ws['A1'] = 42
ws.append(["Name", "Age", "Sex", "Location"])

# print("1 to enter data, 0 to exit")
# print("Number of members?")
# iteration = int(input(prompt))
# count = 1

while(True):
    print("1 to enter data, 0 to exit")
    action = int(input(prompt))
    if action is 1:
# for i in range(iteration):
# while(action == 1):
#     count += 1
        data = []

#     print(i)
        print("Name: ")
        data.append(input(prompt))
#  OR   ws[f"A{i+2}"] = input(prompt)
        print("Age: ")
#  OR   ws[f"B{i+2}"] = input(prompt)
        data.append(input(prompt))
        print("Sex: ")
#  OR   ws[f"C{i+2}"] = input(prompt)
        data.append(input(prompt))
        print("Location: ")
#  OR   ws[f"D{i+2}"] = input(prompt)
        data.append(input(prompt))
        ws.append(data)
    else:
        break
    

#Rows can also be appended
# ws.append([1, 2, 3])

# #Python types will automatically be converter
# import datetime
# ws['A2'] = datetime.datetime.now()

# ws1 = wb.create_sheet("Mysheet") # insert at the end (default)

# ws2 = wb.create_sheet("Mysheet2", 0) # insert at first position

# ws2.Title

#Save the file
wb.save("sample.xlsx")
# Out:
# 1 to enter data, 0 to exit
# ->1
# Name:
# ->KFKDFS
# Age:
# ->GE
# Sex:
# ->F
# Location:
# ->WRE
# 1 to enter data, 0 to exit
# ->1
# Name:
# ->AFAF
# Age:
# ->HTRWH
# Sex:
# ->AF
# Location:
# ->AFG
# 1 to enter data, 0 to exit
# ->0
